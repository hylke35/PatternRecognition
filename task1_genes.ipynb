# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.feature_selection import mutual_info_classif
from sklearn.cluster import KMeans
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import f1_score, confusion_matrix

# %%
data = pd.read_csv("data.csv", index_col=0)
labels = pd.read_csv("labels.csv",index_col=0)
data.head()
data.tail()
# -> 801 rows, 20264 columns
labels.tail()
np.unique(labels)
# -> 5 classes


# (for context: calculated a correlation matrix earlier (VERY computationally inteNsive)) 
# -> gene_5 only has NaN values, probably because of zero variance. Let's drop all columns with zero variance
zero_var_columns = data.columns[data.nunique() <= 1]
data = data.drop(columns=zero_var_columns)
#data.head()

#let's also convert to float32 to speed up computations
data[data.select_dtypes(include=['float64']).columns] = data.select_dtypes(include=['float64']).astype('float32')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 801 entries, sample_0 to sample_800
# Columns: 20264 entries, gene_0 to gene_20530
# dtypes: float32(20264)
# memory usage: 61.9+ MB

# %%
random_seed = 12

# %%
data.head()
# Out:
#           gene_0    gene_1    gene_2    gene_3     gene_4    gene_6    gene_7  \
# sample_0     0.0  2.017209  3.265527  5.478487  10.431999  7.175175  0.591871
# sample_1     0.0  0.592732  1.588421  7.586157   9.623011  6.816049  0.000000
# sample_2     0.0  3.511759  4.327199  6.881787   9.870730  6.972130  0.452595
# sample_3     0.0  3.663618  4.507649  6.659068  10.196184  7.843375  0.434882
# sample_4     0.0  2.655741  2.821547  6.539454   9.738265  6.566967  0.360982
#
#           gene_8  gene_9   gene_10  ...  gene_20521  gene_20522  gene_20523  \
# sample_0     0.0     0.0  0.591871  ...    4.926711    8.210258    9.723516
# sample_1     0.0     0.0  0.000000  ...    4.593372    7.323865    9.740931
# sample_2     0.0     0.0  0.000000  ...    5.125213    8.127123   10.908640
# sample_3     0.0     0.0  0.000000  ...    6.076566    8.792959   10.141520
# sample_4     0.0     0.0  0.000000  ...    5.996032    8.891425   10.373790
#
#           gene_20524  gene_20525  gene_20526  gene_20527  gene_20528  \
# sample_0    7.220030    9.119813   12.003135    9.650743    8.921327
# sample_1    6.256586    8.381612   12.674552   10.517059    9.397854
# sample_2    5.401607    9.911597    9.045255    9.788360   10.090469
# sample_3    8.942804    9.601208   11.392682    9.694814    9.684364
# sample_4    7.181162    9.846910   11.922440    9.217750    9.461191
#
#           gene_20529  gene_20530
# sample_0    5.286759         0.0
# sample_1    2.094168         0.0
# sample_2    1.683023         0.0
# sample_3    3.292001         0.0
# sample_4    5.110372         0.0
#
# [5 rows x 20264 columns]

# %%
# TSNE visualisation

#this because label encoder expects a 1D array
labels_flat = labels.values.ravel()

#this because plt expects classes to be represented numerically
label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels_flat)

#initialize TSNE
tsne = TSNE(n_components=2, random_state=random_seed)

#fit to data
data_tsne = tsne.fit_transform(data)

# plot TSNE Projection for every unique label
plt.figure(figsize=(10, 10))
for cls in np.unique(labels_encoded):
    decoded_label = label_encoder.inverse_transform([cls])[0]
    plt.scatter(data_tsne[labels_encoded == cls, 0], data_tsne[labels_encoded == cls, 1], label=decoded_label, alpha=0.7)

plt.title('t-SNE Projection')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.legend(title='Classes')
plt.show()

# -> classes seem well balanced. Except maybe the -10,-40 one doesn't have much. COAD.
# Also clearly separable. You can see there is that one other point in the biggest cluster, 
# so a performance metric of 1.00 should be suspicious, and may be a sign of overfitting

# %%
# split into trainval and test
X_trainval, X_test, y_trainval, y_test = train_test_split(data, labels, test_size=0.1, random_state=random_seed)
# split trainval into train and val
X_train, X_val, y_train, y_val = train_test_split(X_trainval, y_trainval, test_size=0.1, random_state=random_seed)

y_train_flat = y_train.values.ravel()
y_trainval_flat = y_trainval.values.ravel()
y_test_flat = y_test.values.ravel()

# %%
# RANDOM FOREST hyperparameter tuning with 3-fold cross validation
param_grid_rf3 = {
    'n_estimators': [50, 100],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
}

rf3 = RandomForestClassifier(random_state=random_seed)

grid_search_rf3 = GridSearchCV(estimator=rf,
                           param_grid=param_grid_rf3,
                           cv=3,
                           scoring='f1_weighted',
                           n_jobs=-1,
                           verbose=2)

grid_search_rf3.fit(X_train, y_train_flat)

results_rf3 = grid_search_rf3.cv_results_
for mean_score, params in zip(results_rf3['mean_test_score'], results_rf3['params']):
    print(f"F1 Score: {mean_score:.4f} for {params}")
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# F1 Score: 0.9954 for {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# F1 Score: 0.9954 for {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# F1 Score: 0.9954 for {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50}
# F1 Score: 0.9954 for {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# F1 Score: 0.9969 for {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# F1 Score: 0.9969 for {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# F1 Score: 0.9954 for {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50}
# F1 Score: 0.9954 for {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# F1 Score: 0.9954 for {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# F1 Score: 0.9954 for {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# F1 Score: 0.9954 for {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50}
# F1 Score: 0.9954 for {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# F1 Score: 0.9969 for {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# F1 Score: 0.9969 for {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# F1 Score: 0.9954 for {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50}
# F1 Score: 0.9954 for {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# F1 Score: 0.9954 for {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# F1 Score: 0.9954 for {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# F1 Score: 0.9954 for {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50}
# F1 Score: 0.9954 for {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# F1 Score: 0.9969 for {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# F1 Score: 0.9969 for {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# F1 Score: 0.9954 for {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50}
# F1 Score: 0.9954 for {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}

# %%
# RANDOM FOREST hyperparameter tuning with 7-fold cross validation
param_grid_rf7 = {
    'n_estimators': [50, 100],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
}

rf7 = RandomForestClassifier(random_state=random_seed)

grid_search_rf7 = GridSearchCV(estimator=rf,
                           param_grid=param_grid_rf7,
                           cv=7,
                           scoring='f1_weighted',
                           n_jobs=-1,
                           verbose=2)

grid_search_rf7.fit(X_train, y_train_flat)

results_rf7 = grid_search_rf7.cv_results_
for mean_score, params in zip(results_rf7['mean_test_score'], results_rf7['params']):
    print(f"F1 Score: {mean_score:.4f} for {params}")
# Out:
# Fitting 7 folds for each of 24 candidates, totalling 168 fits
# F1 Score: 0.9938 for {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# F1 Score: 0.9953 for {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# F1 Score: 0.9969 for {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50}
# F1 Score: 0.9953 for {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# F1 Score: 0.9953 for {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# F1 Score: 0.9953 for {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# F1 Score: 0.9953 for {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50}
# F1 Score: 0.9953 for {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# F1 Score: 0.9938 for {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# F1 Score: 0.9953 for {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# F1 Score: 0.9969 for {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50}
# F1 Score: 0.9953 for {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# F1 Score: 0.9953 for {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# F1 Score: 0.9953 for {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# F1 Score: 0.9953 for {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50}
# F1 Score: 0.9953 for {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# F1 Score: 0.9938 for {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# F1 Score: 0.9953 for {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# F1 Score: 0.9969 for {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50}
# F1 Score: 0.9953 for {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# F1 Score: 0.9953 for {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# F1 Score: 0.9953 for {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# F1 Score: 0.9953 for {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50}
# F1 Score: 0.9953 for {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}

# %%
# SVM hyperparameter tuning met 3-fold cross-validation

param_grid_svm3 = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf', 'poly'],
    'degree': [2, 3],  
    'gamma': ['scale', 'auto'], 
}

svm3 = svm.SVC() 

grid_search_svm3 = GridSearchCV(estimator=svm3,
                           param_grid=param_grid_svm3,
                           cv=3,
                           scoring='f1_weighted',
                           n_jobs=-1,
                           verbose=2)

grid_search_svm3.fit(X_train, y_train_flat)

results_svm3 = grid_search_svm3.cv_results_
for mean_score, params in zip(results_svm3['mean_test_score'], results_svm3['params']):
    print(f"F1 Score: {mean_score:.4f} for {params}")
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# F1 Score: 0.9985 for {'C': 0.1, 'degree': 2, 'gamma': 'scale', 'kernel': 'linear'}
# F1 Score: 0.5447 for {'C': 0.1, 'degree': 2, 'gamma': 'scale', 'kernel': 'rbf'}
# F1 Score: 0.9938 for {'C': 0.1, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# F1 Score: 0.9985 for {'C': 0.1, 'degree': 2, 'gamma': 'auto', 'kernel': 'linear'}
# F1 Score: 0.7051 for {'C': 0.1, 'degree': 2, 'gamma': 'auto', 'kernel': 'rbf'}
# F1 Score: 0.9985 for {'C': 0.1, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# F1 Score: 0.9985 for {'C': 0.1, 'degree': 3, 'gamma': 'scale', 'kernel': 'linear'}
# F1 Score: 0.5447 for {'C': 0.1, 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# F1 Score: 0.9969 for {'C': 0.1, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# F1 Score: 0.9985 for {'C': 0.1, 'degree': 3, 'gamma': 'auto', 'kernel': 'linear'}
# F1 Score: 0.7051 for {'C': 0.1, 'degree': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# F1 Score: 0.9985 for {'C': 0.1, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# F1 Score: 0.9985 for {'C': 1, 'degree': 2, 'gamma': 'scale', 'kernel': 'linear'}
# F1 Score: 0.9938 for {'C': 1, 'degree': 2, 'gamma': 'scale', 'kernel': 'rbf'}
# F1 Score: 0.9969 for {'C': 1, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# F1 Score: 0.9985 for {'C': 1, 'degree': 2, 'gamma': 'auto', 'kernel': 'linear'}
# F1 Score: 0.9861 for {'C': 1, 'degree': 2, 'gamma': 'auto', 'kernel': 'rbf'}
# F1 Score: 0.9985 for {'C': 1, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# F1 Score: 0.9985 for {'C': 1, 'degree': 3, 'gamma': 'scale', 'kernel': 'linear'}
# F1 Score: 0.9938 for {'C': 1, 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# F1 Score: 0.9985 for {'C': 1, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# F1 Score: 0.9985 for {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel': 'linear'}
# F1 Score: 0.9861 for {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# F1 Score: 0.9985 for {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# F1 Score: 0.9985 for {'C': 10, 'degree': 2, 'gamma': 'scale', 'kernel': 'linear'}
# F1 Score: 0.9985 for {'C': 10, 'degree': 2, 'gamma': 'scale', 'kernel': 'rbf'}
# F1 Score: 0.9985 for {'C': 10, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# F1 Score: 0.9985 for {'C': 10, 'degree': 2, 'gamma': 'auto', 'kernel': 'linear'}
# F1 Score: 0.9876 for {'C': 10, 'degree': 2, 'gamma': 'auto', 'kernel': 'rbf'}
# F1 Score: 0.9985 for {'C': 10, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# F1 Score: 0.9985 for {'C': 10, 'degree': 3, 'gamma': 'scale', 'kernel': 'linear'}
# F1 Score: 0.9985 for {'C': 10, 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# F1 Score: 0.9985 for {'C': 10, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# F1 Score: 0.9985 for {'C': 10, 'degree': 3, 'gamma': 'auto', 'kernel': 'linear'}
# F1 Score: 0.9876 for {'C': 10, 'degree': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# F1 Score: 0.9985 for {'C': 10, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}

# %%
# SVM hyperparameter tuning met 7-fold cross-validation

param_grid_svm7 = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf', 'poly'],
    'degree': [2, 3],  
    'gamma': ['scale', 'auto'], 
}

svm7 = svm.SVC() 

grid_search_svm7 = GridSearchCV(estimator=svm7,
                           param_grid=param_grid_svm7,
                           cv=7,
                           scoring='f1_weighted',
                           n_jobs=-1,
                           verbose=2)

grid_search_svm7.fit(X_train, y_train_flat)

results_svm7 = grid_search_svm7.cv_results_
for mean_score, params in zip(results_svm7['mean_test_score'], results_svm7['params']):
    print(f"F1 Score: {mean_score:.4f} for {params}")
# Out:
# Fitting 7 folds for each of 36 candidates, totalling 252 fits
# F1 Score: 0.9984 for {'C': 0.1, 'degree': 2, 'gamma': 'scale', 'kernel': 'linear'}
# F1 Score: 0.6726 for {'C': 0.1, 'degree': 2, 'gamma': 'scale', 'kernel': 'rbf'}
# F1 Score: 0.9938 for {'C': 0.1, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# F1 Score: 0.9984 for {'C': 0.1, 'degree': 2, 'gamma': 'auto', 'kernel': 'linear'}
# F1 Score: 0.8445 for {'C': 0.1, 'degree': 2, 'gamma': 'auto', 'kernel': 'rbf'}
# F1 Score: 0.9984 for {'C': 0.1, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# F1 Score: 0.9984 for {'C': 0.1, 'degree': 3, 'gamma': 'scale', 'kernel': 'linear'}
# F1 Score: 0.6726 for {'C': 0.1, 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# F1 Score: 0.9984 for {'C': 0.1, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# F1 Score: 0.9984 for {'C': 0.1, 'degree': 3, 'gamma': 'auto', 'kernel': 'linear'}
# F1 Score: 0.8445 for {'C': 0.1, 'degree': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# F1 Score: 0.9984 for {'C': 0.1, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# F1 Score: 0.9984 for {'C': 1, 'degree': 2, 'gamma': 'scale', 'kernel': 'linear'}
# F1 Score: 0.9953 for {'C': 1, 'degree': 2, 'gamma': 'scale', 'kernel': 'rbf'}
# F1 Score: 0.9984 for {'C': 1, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# F1 Score: 0.9984 for {'C': 1, 'degree': 2, 'gamma': 'auto', 'kernel': 'linear'}
# F1 Score: 0.9860 for {'C': 1, 'degree': 2, 'gamma': 'auto', 'kernel': 'rbf'}
# F1 Score: 0.9984 for {'C': 1, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# F1 Score: 0.9984 for {'C': 1, 'degree': 3, 'gamma': 'scale', 'kernel': 'linear'}
# F1 Score: 0.9953 for {'C': 1, 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# F1 Score: 0.9984 for {'C': 1, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# F1 Score: 0.9984 for {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel': 'linear'}
# F1 Score: 0.9860 for {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# F1 Score: 0.9984 for {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# F1 Score: 0.9984 for {'C': 10, 'degree': 2, 'gamma': 'scale', 'kernel': 'linear'}
# F1 Score: 0.9984 for {'C': 10, 'degree': 2, 'gamma': 'scale', 'kernel': 'rbf'}
# F1 Score: 0.9984 for {'C': 10, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# F1 Score: 0.9984 for {'C': 10, 'degree': 2, 'gamma': 'auto', 'kernel': 'linear'}
# F1 Score: 0.9876 for {'C': 10, 'degree': 2, 'gamma': 'auto', 'kernel': 'rbf'}
# F1 Score: 0.9984 for {'C': 10, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# F1 Score: 0.9984 for {'C': 10, 'degree': 3, 'gamma': 'scale', 'kernel': 'linear'}
# F1 Score: 0.9984 for {'C': 10, 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# F1 Score: 0.9984 for {'C': 10, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# F1 Score: 0.9984 for {'C': 10, 'degree': 3, 'gamma': 'auto', 'kernel': 'linear'}
# F1 Score: 0.9876 for {'C': 10, 'degree': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# F1 Score: 0.9984 for {'C': 10, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}

# %%
# kNN hyperparameter tuning with 3-fold cross validation
param_grid_knn3 = {
    'n_neighbors': [3, 5, 7, 10],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
}

knn3 = KNeighborsClassifier()

grid_search_knn3 = GridSearchCV(estimator=knn3,
                                 param_grid=param_grid_knn3,
                                 cv=3,
                                 scoring='f1_weighted',
                                 n_jobs=-1,
                                 verbose=2)

grid_search_knn3.fit(X_train, y_train_flat)

results_knn3 = grid_search_knn3.cv_results_
for mean_score, params in zip(results_knn3['mean_test_score'], results_knn3['params']):
    print(f"F1 Score: {mean_score:.4f} for {params}")
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# F1 Score: 0.9969 for {'algorithm': 'auto', 'n_neighbors': 3, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'auto', 'n_neighbors': 3, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'auto', 'n_neighbors': 5, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'auto', 'n_neighbors': 5, 'weights': 'distance'}
# F1 Score: 0.9938 for {'algorithm': 'auto', 'n_neighbors': 7, 'weights': 'uniform'}
# F1 Score: 0.9938 for {'algorithm': 'auto', 'n_neighbors': 7, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'auto', 'n_neighbors': 10, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'auto', 'n_neighbors': 10, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'ball_tree', 'n_neighbors': 3, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'ball_tree', 'n_neighbors': 3, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'ball_tree', 'n_neighbors': 5, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'ball_tree', 'n_neighbors': 5, 'weights': 'distance'}
# F1 Score: 0.9938 for {'algorithm': 'ball_tree', 'n_neighbors': 7, 'weights': 'uniform'}
# F1 Score: 0.9938 for {'algorithm': 'ball_tree', 'n_neighbors': 7, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'ball_tree', 'n_neighbors': 10, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'ball_tree', 'n_neighbors': 10, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'kd_tree', 'n_neighbors': 3, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'kd_tree', 'n_neighbors': 3, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'kd_tree', 'n_neighbors': 5, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'kd_tree', 'n_neighbors': 5, 'weights': 'distance'}
# F1 Score: 0.9938 for {'algorithm': 'kd_tree', 'n_neighbors': 7, 'weights': 'uniform'}
# F1 Score: 0.9938 for {'algorithm': 'kd_tree', 'n_neighbors': 7, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'brute', 'n_neighbors': 3, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'brute', 'n_neighbors': 3, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'brute', 'n_neighbors': 5, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'brute', 'n_neighbors': 5, 'weights': 'distance'}
# F1 Score: 0.9938 for {'algorithm': 'brute', 'n_neighbors': 7, 'weights': 'uniform'}
# F1 Score: 0.9938 for {'algorithm': 'brute', 'n_neighbors': 7, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'brute', 'n_neighbors': 10, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'brute', 'n_neighbors': 10, 'weights': 'distance'}

# %%
# kNN hyperparameter tuning with 7-fold cross validation
param_grid_knn7 = {
    'n_neighbors': [3, 5, 7, 10],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
}

knn7 = KNeighborsClassifier()

grid_search_knn7 = GridSearchCV(estimator=knn7,
                                 param_grid=param_grid_knn7,
                                 cv=7,
                                 scoring='f1_weighted',
                                 n_jobs=-1,
                                 verbose=2)

grid_search_knn7.fit(X_train, y_train_flat)

results_knn7 = grid_search_knn7.cv_results_
for mean_score, params in zip(results_knn7['mean_test_score'], results_knn7['params']):
    print(f"F1 Score: {mean_score:.4f} for {params}")
# Out:
# Fitting 7 folds for each of 32 candidates, totalling 224 fits
# F1 Score: 0.9969 for {'algorithm': 'auto', 'n_neighbors': 3, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'auto', 'n_neighbors': 3, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'auto', 'n_neighbors': 5, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'auto', 'n_neighbors': 5, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'auto', 'n_neighbors': 7, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'auto', 'n_neighbors': 7, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'auto', 'n_neighbors': 10, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'auto', 'n_neighbors': 10, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'ball_tree', 'n_neighbors': 3, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'ball_tree', 'n_neighbors': 3, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'ball_tree', 'n_neighbors': 5, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'ball_tree', 'n_neighbors': 5, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'ball_tree', 'n_neighbors': 7, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'ball_tree', 'n_neighbors': 7, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'ball_tree', 'n_neighbors': 10, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'ball_tree', 'n_neighbors': 10, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'kd_tree', 'n_neighbors': 3, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'kd_tree', 'n_neighbors': 3, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'kd_tree', 'n_neighbors': 5, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'kd_tree', 'n_neighbors': 5, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'kd_tree', 'n_neighbors': 7, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'kd_tree', 'n_neighbors': 7, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'brute', 'n_neighbors': 3, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'brute', 'n_neighbors': 3, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'brute', 'n_neighbors': 5, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'brute', 'n_neighbors': 5, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'brute', 'n_neighbors': 7, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'brute', 'n_neighbors': 7, 'weights': 'distance'}
# F1 Score: 0.9969 for {'algorithm': 'brute', 'n_neighbors': 10, 'weights': 'uniform'}
# F1 Score: 0.9969 for {'algorithm': 'brute', 'n_neighbors': 10, 'weights': 'distance'}

# %%
# best Random Forest
best_rf = RandomForestClassifier(max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50, random_state=random_seed)
best_rf.fit(X_train, y_train_flat)
y_pred_val = best_rf.predict(X_val)
f1 = f1_score(y_val, y_pred_val, average='weighted')
print(f'F1 Score: {f1}')
cm = confusion_matrix(y_val, y_pred_val)
print(f"Confusion Matrix:\n{cm}")
# Out:
# F1 Score: 1.0
# Confusion Matrix:
# [[25  0  0  0  0]
#  [ 0  5  0  0  0]
#  [ 0  0 15  0  0]
#  [ 0  0  0 11  0]
#  [ 0  0  0  0 16]]

# %%
# best SVM
best_svm = svm.SVC(C=0.1, gamma='scale', kernel='linear', random_state=random_seed)
best_svm.fit(X_train, y_train_flat)
y_pred_val = best_svm.predict(X_val)
f1 = f1_score(y_val, y_pred_val, average='weighted')
print(f'F1 Score: {f1}')
cm = confusion_matrix(y_val, y_pred_val)
print(f"Confusion Matrix:\n{cm}")
# Out:
# F1 Score: 1.0
# Confusion Matrix:
# [[25  0  0  0  0]
#  [ 0  5  0  0  0]
#  [ 0  0 15  0  0]
#  [ 0  0  0 11  0]
#  [ 0  0  0  0 16]]

# %%
#PCA transform
pca = PCA(n_components = min(data.shape[0], data.shape[1]))
pca_result = pca.fit_transform(data)

# Cumulative variance explained
explained_variance_ratio = np.cumsum(pca.explained_variance_ratio_)
print(explained_variance_ratio)

# split into trainval and test
pcaX_trainval, pcaX_test, pcay_trainval, pcay_test = train_test_split(pca_result, labels, test_size=0.1, random_state=random_seed)
# split trainval into train and val
pcaX_train, pcaX_val, pcay_train, pcay_val = train_test_split(pcaX_trainval, pcay_trainval, test_size=0.1, random_state=random_seed)

pcay_train_flat = pcay_train.values.ravel()
# Out:
# [0.15838563 0.26342523 0.35814747 0.4231555  0.45931166 0.48903832
#  0.51560974 0.53123707 0.5453078  0.55757654 0.56717765 0.57607985
#  0.5836619  0.59089214 0.59753215 0.6039093  0.6096042  0.61477995
#  0.61940116 0.62385625 0.62829083 0.63235515 0.63630986 0.64004177
#  0.6437273  0.64728415 0.650769   0.6539362  0.65704    0.65999234
#  0.66288453 0.66564745 0.66837853 0.670999   0.67351305 0.6760242
#  0.67843056 0.6807873  0.68310905 0.6853635  0.6875836  0.6897585
#  0.69187987 0.6939833  0.6960693  0.6981122  0.70007694 0.70203424
#  0.7039684  0.7058597  0.7076774  0.70946264 0.7112203  0.7129473
#  0.7146514  0.716331   0.71797353 0.7196023  0.7212149  0.7227949
#  0.7243663  0.72592115 0.72746366 0.72897637 0.7304594  0.731936
#  0.73339283 0.73482335 0.7362226  0.7376085  0.73898214 0.74034965
#  0.74169016 0.74302346 0.74434245 0.7456485  0.7469421  0.7482335
#  0.74950844 0.7507729  0.75201863 0.75325114 0.75447094 0.75568515
#  0.7568941  0.7580775  0.7592472  0.7603992  0.76154864 0.76268536
#  0.76381326 0.76493645 0.7660375  0.767134   0.76821774 0.7692952
#  0.7703564  0.7714104  0.77245456 0.77349275 0.7745179  0.7755379
#  0.77655274 0.7775625  0.77855027 0.77953595 0.7805103  0.78147894
#  0.78244156 0.7833995  0.78434855 0.78529227 0.7862304  0.7871649
#  0.7880887  0.78900373 0.7899114  0.79080975 0.7916974  0.79257953
#  0.79345655 0.7943247  0.79519    0.7960517  0.7969033  0.79774815
#  0.7985899  0.7994297  0.80026734 0.80109507 0.8019181  0.80273664
#  0.80354714 0.80435175 0.80515385 0.8059471  0.806739   0.807526
#  0.80830437 0.809081   0.8098529  0.8106179  0.8113805  0.8121394
#  0.8128923  0.81364197 0.814389   0.8151318  0.8158723  0.81660587
#  0.81733865 0.8180682  0.81879365 0.81951725 0.82023484 0.82094896
#  0.82165784 0.822362   0.8230646  0.8237618  0.824455   0.82514423
#  0.8258327  0.82651645 0.8271969  0.8278722  0.8285437  0.82921195
#  0.82987815 0.83053976 0.8311994  0.8318518  0.8324995  0.8331447
#  0.8337857  0.8344243  0.8350609  0.8356934  0.8363229  0.8369497
#  0.83757216 0.83819354 0.83881027 0.83942086 0.84002966 0.840637
#  0.8412411  0.8418433  0.84244484 0.84304357 0.8436382  0.84423006
#  0.84482074 0.845407   0.8459897  0.8465694  0.84714746 0.84772444
#  0.84829634 0.84886503 0.8494314  0.8499957  0.8505582  0.8511184
#  0.8516773  0.8522319  0.85278404 0.8533357  0.8538834  0.85443
#  0.85497403 0.85551566 0.85605633 0.85659546 0.85713226 0.8576651
#  0.85819566 0.8587234  0.8592507  0.859774   0.8602945  0.86081153
#  0.86132735 0.8618419  0.8623539  0.8628648  0.8633745  0.8638828
#  0.8643898  0.86489373 0.8653945  0.8658931  0.86639    0.86688596
#  0.86737967 0.8678713  0.868361   0.8688491  0.86933696 0.86982137
#  0.87030315 0.87078404 0.87126213 0.87173826 0.87221324 0.87268674
#  0.87315893 0.8736308  0.8741002  0.8745688  0.8750324  0.8754949
#  0.87595576 0.8764161  0.876874   0.87733024 0.8777846  0.8782386
#  0.87869006 0.8791403  0.8795896  0.88003707 0.88048327 0.8809283
#  0.8813714  0.88181305 0.8822523  0.88269037 0.8831259  0.88355935
#  0.88399214 0.8844231  0.8848518  0.8852795  0.8857055  0.88613063
#  0.8865546  0.8869774  0.88739926 0.8878201  0.88824004 0.88865787
#  0.8890742  0.8894883  0.88990057 0.89031154 0.8907218  0.89113104
#  0.89153767 0.89194405 0.8923494  0.89275163 0.89315295 0.893553
#  0.89395225 0.8943504  0.8947481  0.8951444  0.89553905 0.89593285
#  0.89632565 0.89671725 0.89710695 0.89749485 0.8978815  0.8982676
#  0.8986521  0.899036   0.8994186  0.8997992  0.9001779  0.90055645
#  0.90093416 0.90131044 0.901685   0.902058   0.9024303  0.90280175
#  0.9031726  0.90354174 0.9039098  0.90427643 0.90464246 0.90500575
#  0.90536815 0.9057299  0.9060901  0.90645015 0.9068083  0.90716594
#  0.90752155 0.9078769  0.9082313  0.9085844  0.90893704 0.9092883
#  0.9096384  0.9099864  0.9103343  0.91068166 0.9110262  0.91137064
#  0.91171396 0.9120556  0.9123965  0.91273683 0.9130759  0.9134143
#  0.91375136 0.9140879  0.9144242  0.9147594  0.91509414 0.91542673
#  0.915758   0.9160879  0.9164175  0.9167462  0.9170737  0.9174006
#  0.91772586 0.9180508  0.9183746  0.9186975  0.9190197  0.91934097
#  0.91966003 0.9199786  0.92029536 0.92061156 0.9209273  0.9212423
#  0.9215565  0.92186946 0.9221816  0.9224924  0.9228028  0.92311233
#  0.9234203  0.92372763 0.9240342  0.9243405  0.92464536 0.92494917
#  0.9252527  0.92555577 0.9258575  0.9261583  0.9264584  0.926758
#  0.9270573  0.9273558  0.9276531  0.92794985 0.9282451  0.9285396
#  0.9288333  0.9291268  0.92941916 0.92971057 0.9300007  0.9302898
#  0.930578   0.93086565 0.9311527  0.9314385  0.9317235  0.9320074
#  0.9322908  0.9325734  0.932855   0.9331361  0.9334161  0.93369555
#  0.9339744  0.93425286 0.9345306  0.93480814 0.9350852  0.9353614
#  0.93563694 0.9359114  0.93618566 0.9364582  0.9367301  0.93700117
#  0.9372718  0.9375416  0.9378112  0.93808043 0.9383493  0.938617
#  0.93888414 0.9391498  0.9394149  0.93967956 0.9399435  0.940207
#  0.94046986 0.9407321  0.9409938  0.94125414 0.941514   0.9417731
#  0.9420315  0.94228846 0.94254494 0.9428013  0.94305634 0.94331056
#  0.9435646  0.9438179  0.9440706  0.9443224  0.94457316 0.9448232
#  0.94507307 0.94532126 0.9455692  0.9458168  0.9460638  0.9463101
#  0.9465558  0.9468011  0.9470457  0.9472899  0.947533   0.9477759
#  0.948018   0.9482594  0.94850063 0.94874054 0.9489798  0.9492187
#  0.94945633 0.94969296 0.94992936 0.95016545 0.9504008  0.95063543
#  0.95087    0.95110375 0.95133716 0.95156956 0.9518015  0.9520332
#  0.95226395 0.95249414 0.9527236  0.9529523  0.9531807  0.95340854
#  0.95363575 0.95386237 0.95408756 0.9543127  0.9545369  0.9547608
#  0.95498407 0.95520705 0.95542955 0.9556516  0.9558727  0.9560936
#  0.9563137  0.9565332  0.9567522  0.9569699  0.9571871  0.9574041
#  0.9576208  0.957837   0.9580525  0.95826757 0.95848167 0.95869565
#  0.9589087  0.9591215  0.95933414 0.959546   0.9597568  0.95996743
#  0.96017677 0.96038604 0.960595   0.9608032  0.96101046 0.9612171
#  0.9614233  0.96162915 0.9618346  0.9620393  0.96224326 0.9624468
#  0.96264976 0.9628524  0.96305424 0.96325576 0.96345663 0.96365696
#  0.9638568  0.96405655 0.9642548  0.964453   0.9646507  0.96484774
#  0.965044   0.96524006 0.9654355  0.9656308  0.9658254  0.96601975
#  0.96621335 0.96640646 0.9665986  0.9667903  0.9669813  0.967172
#  0.9673626  0.9675528  0.9677424  0.9679315  0.96812016 0.9683083
#  0.9684959  0.9686833  0.96887004 0.9690561  0.969242   0.969427
#  0.96961105 0.9697946  0.96997774 0.9701607  0.97034305 0.97052485
#  0.9707064  0.97088724 0.97106767 0.97124773 0.97142744 0.971607
#  0.9717855  0.97196287 0.9721399  0.9723162  0.97249234 0.9726679
#  0.97284335 0.973018   0.9731922  0.973366   0.9735397  0.9737128
#  0.97388524 0.9740576  0.9742297  0.9744017  0.97457284 0.9747433
#  0.9749136  0.97508335 0.97525275 0.9754215  0.97558945 0.9757573
#  0.9759247  0.9760916  0.9762585  0.9764249  0.97658974 0.976754
#  0.9769181  0.9770819  0.977245   0.9774077  0.9775701  0.9777325
#  0.97789437 0.9780558  0.97821695 0.9783779  0.9785378  0.978697
#  0.9788558  0.97901416 0.97917235 0.9793301  0.9794875  0.9796444
#  0.9798008  0.979957   0.98011243 0.98026764 0.9804224  0.9805764
#  0.98073024 0.9808837  0.98103696 0.9811895  0.98134184 0.981494
#  0.981646   0.98179716 0.98194754 0.9820976  0.9822472  0.98239607
#  0.98254454 0.9826929  0.98284096 0.98298854 0.98313534 0.9832818
#  0.98342806 0.98357373 0.9837186  0.9838633  0.9840074  0.984151
#  0.9842945  0.9844375  0.9845798  0.98472166 0.9848631  0.98500407
#  0.98514485 0.9852851  0.9854251  0.98556465 0.9857038  0.98584294
#  0.9859816  0.9861196  0.9862572  0.98639464 0.98653173 0.9866686
#  0.986805   0.9869411  0.98707694 0.98721236 0.9873475  0.987482
#  0.9876158  0.98774946 0.98788226 0.9880144  0.98814625 0.988278
#  0.98840934 0.98854023 0.98867065 0.98880064 0.98893017 0.9890594
#  0.9891885  0.9893171  0.98944527 0.9895729  0.9896998  0.9898265
#  0.9899528  0.99007845 0.9902037  0.9903287  0.9904535  0.990578
#  0.99070185 0.9908251  0.99094826 0.9910708  0.99119276 0.9913143
#  0.9914354  0.9915562  0.9916767  0.99179643 0.9919158  0.9920346
#  0.99215305 0.9922714  0.9923892  0.99250656 0.9926236  0.99274004
#  0.99285597 0.9929716  0.99308646 0.99320114 0.99331534 0.9934293
#  0.99354285 0.9936556  0.99376816 0.99388033 0.9939918  0.9941028
#  0.9942135  0.99432397 0.994434   0.99454355 0.9946527  0.9947614
#  0.9948699  0.99497825 0.9950859  0.9951927  0.99529904 0.99540484
#  0.9955101  0.99561524 0.99572    0.9958245  0.9959279  0.9960308
#  0.9961331  0.9962353  0.99633694 0.99643826 0.9965391  0.9966395
#  0.9967395  0.9968389  0.9969376  0.9970357  0.9971335  0.9972307
#  0.99732774 0.99742436 0.9975202  0.9976157  0.99771047 0.9978048
#  0.99789846 0.9979917  0.99808437 0.99817604 0.9982675  0.9983582
#  0.99844867 0.9985378  0.9986262  0.99871397 0.9988016  0.9988885
#  0.99897504 0.9990599  0.99914426 0.99922794 0.99931103 0.9993932
#  0.999474   0.99955404 0.9996318  0.9997088  0.99978393 0.99985707
#  0.999929   1.0000005  1.0000005 ]

# %%
# best_RF met verschillende hoeveelheden PCA-transformed features (LET OP: deze berekening duurt lang)
best_rf = RandomForestClassifier(max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50, random_state=random_seed)

features = range(1, pcaX_train.shape[1])
f1_scores_rf_pca = np.zeros(pcaX_train.shape[1])


for i in range(1,pcaX_train.shape[1]+1):
    best_rf.fit(pcaX_train[:, :i], pcay_train_flat)
    pcay_pred_val = best_rf.predict(pcaX_val[:, :i])
    f1 = f1_score(pcay_val, pcay_pred_val, average='weighted')
    f1_scores_rf_pca[i-1] = f1

# %%
# Plot best_rf performance vs no of PCA-transformed features
x_values = np.arange(1,802)

plt.figure(figsize=(15,6))
plt.plot(x_values, f1_scores_rf_pca, linestyle='-', color='b', alpha=0.7)
plt.title('F1 scores for best RF by number of PCA-transformed features')
plt.xlabel('Number of (PCA-transformed) Features')
plt.ylabel('F1 score')
plt.show()

# %%
# best_SVM met verschillende hoeveelheden PCA_transformed features
best_svm = svm.SVC(C=0.1, gamma='scale', kernel='linear', random_state=random_seed)

#features = range(1, pcaX_train.shape[1])

# set max features
max_features = 25

#eerst maar een lege array want dat is efficienter
f1_scores_svm_pca = np.zeros(min(max_features, pcaX_train.shape[1]))


for i in range(1,min(max_features, pcaX_train.shape[1])+1):
    best_svm.fit(pcaX_train[:, :i], pcay_train_flat)
    pcay_pred_val = best_svm.predict(pcaX_val[:, :i])
    f1 = f1_score(pcay_val, pcay_pred_val, average='weighted')
    f1_scores_svm_pca[i-1] = f1

# %%
# Plot best_svm performance vs no. of PCA transformed features
x_values = np.arange(1,min(max_features, pcaX_train.shape[1])+1)

plt.figure(figsize=(15,6))
plt.plot(x_values, f1_scores_svm_pca, linestyle='-', color='b', alpha=0.7)
plt.title('F1 scores for best SVM by number of PCA-transformed features')
plt.xlabel('Number of (PCA-transformed) Features')
plt.ylabel('F1 score')
plt.show()

# %%
# FURTHER EXPLORATION OF PCA TRANSFORM

# wat zijn die eerste waarden nou precies?
f1_scores_rf_pca
f1_scores_svm_pca
# ok dat betekent dat we met twee features al een performance hebben van 98.64% en 92.27%. Hoe ziet de data eruit in deze 2-dimensional space?

# drop de andere 798 features
pca_result_2d = pca_result[:,:2]

# plot PCA-2 Projection for every unique label
plt.figure(figsize=(10, 10))
for cls in np.unique(labels_encoded):
    decoded_label = label_encoder.inverse_transform([cls])[0]
    plt.scatter(pca_result_2d[labels_encoded == cls, 0], pca_result_2d[labels_encoded == cls, 1], label=decoded_label, alpha=0.7)

plt.title('PCA Projection')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.legend(title='Classes')
plt.show()

#ok it does do a pretty good job separating the clusters, so I can imagine adding a third dimension already bumps up the F1 score to 1.0

# %%
# calculate mutual information for every feature (takes a while)
mutual_info = mutual_info_classif(X_train, y_train_flat)

# %%
#SORT COLUMNS BY MUTUAL INFORMATION

# convert to pandas df because X_train is one as well
mutual_info_df = pd.DataFrame(mutual_info, index=X_train.columns, columns=['Mutual Information'])

mi_sorted = mutual_info_df.sort_values(by='Mutual Information', ascending=False)
miX_train = X_train[mi_sorted.index]
miX_val = X_val[mi_sorted.index]

# %%
# CALCULATE F1 SCORES FOR RANDOM FOREST USING DIFFERENT AMOUNTS OF FEATURES (sorted by mutual information)

# set top k features for mutual information (mi) calculation
mi_k = 50

# best_RF met verschillende hoeveelheden mi-sorted features
best_rf = RandomForestClassifier(max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50, random_state=random_seed)

#initialize f1 array
f1_scores_rf_mi = np.zeros(mi_k)


for i in range(1,mi_k+1):
    best_rf.fit(miX_train.iloc[:, :i], y_train_flat)
    y_pred_val = best_rf.predict(miX_val.iloc[:, :i])
    f1 = f1_score(y_val, y_pred_val, average='weighted')
    f1_scores_rf_mi[i-1] = f1

# %%
# Plot best_rf performance vs no of mi-sorted features
x_values = np.arange(1,mi_k+1)

plt.figure(figsize=(10,6))
plt.plot(x_values, f1_scores_rf_mi, linestyle='-', color='b', alpha=0.7)
plt.title('F1 scores for best RF by number of MI-sorted features')
plt.xlabel('Number of (MI-sorted) Features')
plt.ylabel('F1 score')
plt.show()

# %%
# CALCULATE F1 SCORES FOR SVM USING DIFFERENT AMOUNTS OF FEATURES (sorted by mutual information)

# set top k features for mutual information (mi) calculation
mi_k = 50

# best_RF met verschillende hoeveelheden mi-sorted features
best_svm = svm.SVC(C=0.1, gamma='scale', kernel='linear', random_state=random_seed)

#initialize f1 array
f1_scores_svm_mi = np.zeros(mi_k)


for i in range(1,mi_k+1):
    best_svm.fit(miX_train.iloc[:, :i], y_train_flat)
    y_pred_val = best_svm.predict(miX_val.iloc[:, :i])
    f1 = f1_score(y_val, y_pred_val, average='weighted')
    f1_scores_svm_mi[i-1] = f1

# %%
# Plot best_rf performance vs no of mi-sorted features
x_values = np.arange(1,mi_k+1)

plt.figure(figsize=(10,6))
plt.plot(x_values, f1_scores_svm_mi, linestyle='-', color='b', alpha=0.7)
plt.title('F1 scores for best SVM by number of MI-sorted features')
plt.xlabel('Number of (MI-sorted) Features')
plt.ylabel('F1 score')
plt.show()

# %%
#FURTHER EXPLORATION OF MUTUAL INFORMATION

#ok voor de beste random forest heb je met twee features met de hoogste MI al een F1 van 89,07% en met de beste SVM 86,88%
# hoe separable zijn de classes in deze twee features?
miX = data[mi_sorted.index]
miX_2d = miX.iloc[:,:2]
miX_2d = miX_2d.to_numpy()

# plot PCA-2 Projection for every unique label
plt.figure(figsize=(10, 10))
for cls in np.unique(labels_encoded):
    decoded_label = label_encoder.inverse_transform([cls])[0]
    plt.scatter(miX_2d[labels_encoded == cls, 0],miX_2d[labels_encoded == cls, 1], label=decoded_label, alpha=0.7)

plt.title('Two features with highest MI')
plt.xlabel('Gene 7964')
plt.ylabel('Gene 18381')
plt.legend(title='Classes')
plt.show()

#ok so with just two genes we can already separate pretty reliably between every pair except COAD and LUAD

# %%
# CLUSTERING
# k-means is appropriate cause Fuzzy C-means may get computationally intensive, and the PCA suggests clusters may be somewhat spherical

# k-means on PCA

#k is five because five labels in dataset
k_clusters = 5

kmeans_pca = KMeans(n_clusters=k_clusters, random_state=random_seed)
kmeans_pca.fit(pca_result)

labels_kmeans_pca = kmeans_pca.labels_

# Plot the results
plt.figure(figsize=(10, 10))
scatter = plt.scatter(pca_result[:, 0], pca_result[:, 1], c=labels_kmeans_pca, cmap='viridis', alpha=0.7)

# Create a legend for the clusters
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=scatter.cmap(scatter.norm(i)), markersize=10) for i in range(k_clusters)]
plt.legend(handles, [f'Cluster {i}' for i in range(k_clusters)], title='Clusters')

plt.title('K-Means Clustering with top PCA components')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.show()

# %%
# k means on original data (best two features as measured using mutual information)
k_clusters = 5

kmeans_mi = KMeans(n_clusters=k_clusters, random_state=random_seed)
kmeans_mi.fit(miX)

labels_kmeans_mi = kmeans_mi.labels_

# Plot the results
plt.figure(figsize=(10, 10))
scatter = plt.scatter(miX.iloc[:, 0], miX.iloc[:, 1], c=labels_kmeans_mi, cmap='viridis', alpha=0.7)

# Create a legend for the clusters
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=scatter.cmap(scatter.norm(i)), markersize=10) for i in range(k_clusters)]
plt.legend(handles, [f'Cluster {i}' for i in range(k_clusters)], title='Clusters', loc='best')

plt.title('K-Means Clustering on original data')
plt.xlabel('Gene 7964')
plt.ylabel('Gene 18381')
plt.show()

# %%
# ENSEMBLE 

# initiate best models
best_rf = RandomForestClassifier(max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50, random_state=random_seed)
best_svm = svm.SVC(C=0.1, gamma='scale', kernel='linear', random_state=random_seed)
best_knn = KNeighborsClassifier(algorithm='auto', n_neighbors=3, weights='uniform')

# create voting classifier with majority voting
ensemble = VotingClassifier(estimators=[
    ('knn', best_knn), 
    ('svm', best_svm), 
    ('rf', best_rf)
], voting='hard')

ensemble.fit(X_trainval, y_trainval.values.ravel())

y_pred_ensemble = ensemble.predict(X_test)

f1_ensemble = f1_score(y_test.values.ravel(), y_pred_ensemble, average='weighted')
cm_ensemble = confusion_matrix(y_test.values.ravel(), y_pred_ensemble)
print(f'Ensemble F1 Score: {f1_ensemble}')
print(f"Confusion Matrix:\n{cm_ensemble}")

#performance of ensemble on test set
# Out:
# Ensemble F1 Score: 1.0
# Confusion Matrix:
# [[29  0  0  0  0]
#  [ 0  8  0  0  0]
#  [ 0  0 11  0  0]
#  [ 0  0  0 19  0]
#  [ 0  0  0  0 14]]
